# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
wave = pd.read_csv("wave.csv")

# %%
plt.magnitude_spectrum(wave['i_data'], color ='green', Fs=20e6, scale='dB') 
plt.show()

# %%
plt.magnitude_spectrum(wave['o_data'].loc[wave['o_ready'] == 1], color ='green', Fs=20e6/32, scale='dB') 
#plt.magnitude_spectrum(wave['o_data'], color ='green', Fs=10e6, scale='dB') 
plt.show()

# %%
wave['i_data'].plot()
# Out:
# <AxesSubplot:>

# %%
wave['integrated_data'].plot()
# Out:
# <AxesSubplot:>

# %%
wave['decimated_data'].plot()
# Out:
# <AxesSubplot:>

# %%
wave['o_data'].loc[wave['o_ready'] == 1].plot()
# Out:
# <AxesSubplot:>

# %%
wave['comb'] = wave['o_ready'] - wave['o_ready'].shift(+3)
wave = wave.dropna()
plt.magnitude_spectrum(wave['comb'], color ='green', Fs=10e6, scale='dB') 
plt.show()

# %%
wave.dropna()
# Out:
#       Unnamed: 0  o_data  o_ready  comb
# 3              3     0.0      1.0   0.0
# 4              4     0.0      1.0   0.0
# 5              5     0.0     -1.0  -2.0
# 6              6     0.0     -1.0  -2.0
# 7              7     0.0      1.0   0.0
# ...          ...     ...      ...   ...
# 9995        9995     2.0      1.0   2.0
# 9996        9996     2.0     -1.0   0.0
# 9997        9997     2.0      1.0   2.0
# 9998        9998     2.0      1.0   0.0
# 9999        9999     2.0     -1.0   0.0
#
# [9997 rows x 4 columns]

# %%
wave['o_data'].loc[wave['o_ready'] == 1]
# Out:
# 0        0.0
# 8        6.0
# 16       6.0
# 24       6.0
# 32       6.0
#         ...
# 9960   -12.0
# 9968   -10.0
# 9976   -10.0
# 9984   -14.0
# 9992   -16.0
# Name: o_data, Length: 1250, dtype: float64

# %%
from scipy import signal

# %%
signal.sq
